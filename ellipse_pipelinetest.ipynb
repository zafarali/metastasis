# %% [markdown]
# # Data processing

# %%
from cc3dtools.PostProcess import PostProcess, SpacePlot
from cc3dtools.GenomeCompare import GenomeCompare

# %%
gc = GenomeCompare.from_gen2_file('./simulation_out/eccentric/genomes_Tue_Aug_25_14:41:02_2015.csv.gen2')
pp = PostProcess(end_file='./simulation_out/eccentric/finish_cells_Tue_Aug_25_14:41:02_2015.csv', gc=gc)

# %%
method_parameters = {
    "N_points": 20,
    "max_cells":500,
    "radius": 50,
    "min_cells": 20,
    "ecc_steps": 0.1,
    "cell_steps": 5,
    "lattice_size": 1000
}

# %%
pp.eccentric_sampling_strategy(**method_parameters)
# Out:
# {'results': [{'eccentricity': 0.0,
#    'samples': [{'E_of_pi': 0.58659518313327186, 'sample_size': 20, 'skips': 0},
#     {'E_of_pi': 0.83903437079153798, 'sample_size': 50, 'skips': 0},
#     {'E_of_pi': 1.0721448355913892, 'sample_size': 100, 'skips': 0},
#     {'E_of_pi': 1.2108158923777581, 'sample_size': 200, 'skips': 0},
#     {'E_of_pi': 1.7139031547948083, 'sample_size': 500, 'skips': 0}]},
#   {'eccentricity': 0.10000000000000001,
#    'samples': [{'E_of_pi': 0.5611104185903355, 'sample_size': 20, 'skips': 0},
#     {'E_of_pi': 0.85708992634709347, 'sample_size': 50, 'skips': 0},
#     {'E_of_pi': 1.0675560178157579, 'sample_size': 100, 'skips': 0},
#     {'E_of_pi': 1.2121991034417428, 'sample_size': 200, 'skips': 0},
#     {'E_of_pi': 1.7139031547948083, 'sample_size': 500, 'skips': 0}]},
#   {'eccentricity': 0.20000000000000001,
#    'samples': [{'E_of_pi': 0.5611104185903355, 'sample_size': 20, 'skips': 0},
# ...

# %%
results = {'results': [{'eccentricity': 0.0,
   'samples': [{'E_of_pi': 0.58659518313327186, 'sample_size': 20, 'skips': 0},
    {'E_of_pi': 0.83903437079153798, 'sample_size': 50, 'skips': 0},
    {'E_of_pi': 1.0721448355913892, 'sample_size': 100, 'skips': 0},
    {'E_of_pi': 1.2108158923777581, 'sample_size': 200, 'skips': 0},
    {'E_of_pi': 1.7139031547948083, 'sample_size': 500, 'skips': 0}]},
  {'eccentricity': 0.10000000000000001,
   'samples': [{'E_of_pi': 0.5611104185903355, 'sample_size': 20, 'skips': 0},
    {'E_of_pi': 0.85708992634709347, 'sample_size': 50, 'skips': 0},
    {'E_of_pi': 1.0675560178157579, 'sample_size': 100, 'skips': 0},
    {'E_of_pi': 1.2121991034417428, 'sample_size': 200, 'skips': 0},
    {'E_of_pi': 1.7139031547948083, 'sample_size': 500, 'skips': 0}]},
  {'eccentricity': 0.20000000000000001,
   'samples': [{'E_of_pi': 0.5611104185903355, 'sample_size': 20, 'skips': 0},
    {'E_of_pi': 0.86871132991607958, 'sample_size': 50, 'skips': 0},
    {'E_of_pi': 1.0853618794625288, 'sample_size': 100, 'skips': 0},
    {'E_of_pi': 1.2301738649068088, 'sample_size': 200, 'skips': 0},
    {'E_of_pi': 1.7269127336654702, 'sample_size': 500, 'skips': 0}]},
  {'eccentricity': 0.30000000000000004,
   'samples': [{'E_of_pi': 0.5611104185903355, 'sample_size': 20, 'skips': 0},
    {'E_of_pi': 0.86621021637542539, 'sample_size': 50, 'skips': 0},
    {'E_of_pi': 1.0522566545335221, 'sample_size': 100, 'skips': 0},
    {'E_of_pi': 1.2295558692214541, 'sample_size': 200, 'skips': 0},
    {'E_of_pi': 1.7235706660513206, 'sample_size': 500, 'skips': 0}]},
  {'eccentricity': 0.40000000000000002,
   'samples': [{'E_of_pi': 0.60364061626497334, 'sample_size': 20, 'skips': 0},
    {'E_of_pi': 0.88641568781246816, 'sample_size': 50, 'skips': 0},
    {'E_of_pi': 1.0585601041891155, 'sample_size': 100, 'skips': 0},
    {'E_of_pi': 1.2684104398585732, 'sample_size': 200, 'skips': 0},
    {'E_of_pi': 1.7500130251451644, 'sample_size': 500, 'skips': 0}]},
  {'eccentricity': 0.5,
   'samples': [{'E_of_pi': 0.56329154382310298, 'sample_size': 20, 'skips': 0},
    {'E_of_pi': 0.90695325094378132, 'sample_size': 50, 'skips': 0},
    {'E_of_pi': 1.0905328940418695, 'sample_size': 100, 'skips': 0},
    {'E_of_pi': 1.3066358524640342, 'sample_size': 200, 'skips': 0},
    {'E_of_pi': 1.7622755338137825, 'sample_size': 500, 'skips': 0}]},
  {'eccentricity': 0.60000000000000009,
   'samples': [{'E_of_pi': 0.5610880463219452, 'sample_size': 20, 'skips': 0},
    {'E_of_pi': 0.92591072720483558, 'sample_size': 50, 'skips': 0},
    {'E_of_pi': 1.1335430725791305, 'sample_size': 100, 'skips': 0},
    {'E_of_pi': 1.3399936434833282, 'sample_size': 200, 'skips': 0},
    {'E_of_pi': 1.7055850751439756, 'sample_size': 500, 'skips': 0}]},
  {'eccentricity': 0.70000000000000007,
   'samples': [{'E_of_pi': 0.60385445935049309, 'sample_size': 20, 'skips': 0},
    {'E_of_pi': 0.98223182130612197, 'sample_size': 50, 'skips': 0},
    {'E_of_pi': 1.2070731153787988, 'sample_size': 100, 'skips': 0},
    {'E_of_pi': 1.4441053307424396, 'sample_size': 200, 'skips': 0},
    {'E_of_pi': 1.8040870322697287, 'sample_size': 500, 'skips': 0}]},
  {'eccentricity': 0.80000000000000004,
   'samples': [{'E_of_pi': 0.63627292170311667, 'sample_size': 20, 'skips': 0},
    {'E_of_pi': 1.0869286071349009, 'sample_size': 50, 'skips': 0},
    {'E_of_pi': 1.2875191355774651, 'sample_size': 100, 'skips': 0},
    {'E_of_pi': 1.4760413516444053, 'sample_size': 200, 'skips': 0},
    {'E_of_pi': 1.845741510304713, 'sample_size': 500, 'skips': 0}]},
  {'eccentricity': 0.90000000000000002,
   'samples': [{'E_of_pi': 0.79990521338274323, 'sample_size': 20, 'skips': 0},
    {'E_of_pi': 1.2198742265080198, 'sample_size': 50, 'skips': 0},
    {'E_of_pi': 1.4249501045817952, 'sample_size': 100, 'skips': 0},
    {'E_of_pi': 1.6301557943732443, 'sample_size': 200, 'skips': 0},
    {'E_of_pi': 1.9737998895196955, 'sample_size': 500, 'skips': 0}]}]}

results = results['results']

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Raw Results

# %%
plt.figure()

color = plt.cm.rainbow(np.linspace(0,1,len(results)))

for i, result in enumerate(results):
    ecc = result['eccentricity']   
    x = []
    y = []
#     labels.append('e='+str(ecc))

    for sample in result['samples']:
        x.append(sample['sample_size'])
        y.append(sample['E_of_pi'])

    plt.plot(x, y, 'x', color=color[i], label='e='+str(ecc), ms=6)

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.5), fancybox=True, ncol=5)
#         print sample['sample_size'], sample['E_of_pi']
plt.xlabel('Sample Size')
plt.ylabel('E(pi)')
plt.show()

# %% [markdown]
# # 1st Degree Poly Fit (Linear Fit)

# %%
plt.figure()

color = plt.cm.rainbow(np.linspace(0,1,len(results)))

for i, result in enumerate(results):
    ecc = result['eccentricity']   
    x = []
    y = []
#     labels.append('e='+str(ecc))

    for sample in result['samples']:
        x.append(sample['sample_size'])
        y.append(sample['E_of_pi'])
    
    z = np.polyfit(x,y,1)
    f = np.poly1d(z)
    x2 = np.linspace(0,500)
    plt.plot(x, y,  'x', color=color[i], label='e='+str(ecc), ms=10)
    plt.plot(x2, f(x2), color=color[i], label='e='+str(ecc)+'(fitted)')

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.5), fancybox=True, ncol=5)
#         print sample['sample_size'], sample['E_of_pi']
plt.xlabel('Sample Size')
plt.ylabel('E(pi)')
plt.show()

# %% [markdown]
# # 2nd Degree Poly Fit

# %%
plt.figure()

color = plt.cm.rainbow(np.linspace(0,1,len(results)))

for i, result in enumerate(results):
    ecc = result['eccentricity']   
    x = []
    y = []
#     labels.append('e='+str(ecc))

    for sample in result['samples']:
        x.append(sample['sample_size'])
        y.append(sample['E_of_pi'])
    
    z = np.polyfit(x,y,2)
    f = np.poly1d(z)
    x2 = np.linspace(0,500)
    plt.plot(x, y,  'x', color=color[i], label='e='+str(ecc), ms=10)
    plt.plot(x2, f(x2), color=color[i], label='e='+str(ecc)+'(fitted)')

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.5), fancybox=True, ncol=5)
#         print sample['sample_size'], sample['E_of_pi']
plt.xlabel('Sample Size')
plt.ylabel('E(pi)')
plt.show()

# %% [markdown]
# # 3rd Degree Poly Fit

# %%
plt.figure()

color = plt.cm.rainbow(np.linspace(0,1,len(results)))

for i, result in enumerate(results):
    ecc = result['eccentricity']   
    x = []
    y = []
#     labels.append('e='+str(ecc))

    for sample in result['samples']:
        x.append(sample['sample_size'])
        y.append(sample['E_of_pi'])
    
    z = np.polyfit(x,y,3)
    f = np.poly1d(z)
    x2 = np.linspace(0,500)
    plt.plot(x, y,  'x', color=color[i], label='e='+str(ecc), ms=10)
    plt.plot(x2, f(x2), color=color[i], label='e='+str(ecc)+'(fitted)')

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.5), fancybox=True, ncol=5)
#         print sample['sample_size'], sample['E_of_pi']
plt.xlabel('Sample Size')
plt.ylabel('E(pi)')
plt.show()
