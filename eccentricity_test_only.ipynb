# %%
from cc3dtools.GenomeCompare import GenomeCompare
from cc3dtools.PostProcess import EccentricityProcessing, PostProcess

# %%
gc = GenomeCompare.from_gen2_file('../simulation_out/labour_simulations/labour_weekend/Limbo1stOrder_Tuesday_08092015_043601/genomes_Tue_Sep__8_04:36:11_2015.csv.gen2')
pp = PostProcess('../simulation_out/labour_simulations/labour_weekend/Limbo1stOrder_Tuesday_08092015_043601/finish_cells_Tue_Sep__8_04:36:11_2015.csv', gc=gc)

# %%
method_parameters={
    "N_points": 20,
    "max_cells":500,
    "radius": 50,
    "percentage_cancer":0.89,
    "min_cells": 20,
    "ecc_steps": 0.1,
    "cell_steps": 5,
    "lattice_size": 1000
}

results = pp.eccentric_sampling_strategy(20,500,radius=50,min_cells=20,ecc_steps=0.1,cell_steps=5,lattice_size=1000,percentage_cancer=0.89)

# %%
parsed = EccentricityProcessing.parse_results(results)

# %%
parsed

# %%
EccentricityProcessing.plot_Epi_vs_A(parsed, 'hey.png')

# %%
results
# Out:
# {'largeA_N': [{'S': [3560.7399999999998,
#     13491.040000000001,
#     22942,
#     29948,
#     35212,
#     41958,
#     49107,
#     54288,
#     61563,
#     64124,
#     73871,
#     73049,
#     83343,
#     87478,
#     92086,
#     100483,
#     100321,
#     104915,
#     110083,
#     114501],
#    'eccentricity': 0.0,
#    'k': [2,
#     12,
#     22,
#     32,
#     42,
#     52,
#     62,
#     72,
#     82,
#     92,
#     102,
#     112,
#     122,
#     132,
#     142,
#     152,
#     162,
#     172,
#     182,
#     192]},
#   {'S': [3623.4499999999998,
#     13278.58,
#     18459,
#     27739,
#     36208,
#     45317,
#     51703,
#     52032,
#     57517,
#     60717,
#     71290,
#     77189,
#     80839,
#     86203,
#     93654,
#     96167,
#     96516,
#     104632,
#     112073,
#     113549],
#    'eccentricity': 0.10000000000000001,
#    'k': [2,
#     12,
#     22,
#     32,
#     42,
#     52,
#     62,
#     72,
#     82,
#     92,
#     102,
# ...
