# %%
from cc3dtools.Lineage import MultiLineage

# %%
ml = MultiLineage( file_name = './data2/division_events_Mon_Jun_15_15:18:22_2015.csv' ) 
#unfortunately CC3D always saves our output files in awkward places

#ml.num_lineages()

# %%
print ml.lineages[9]['lineage'].get_descendants()
print ml.lineages[9]['lineage'].get_branch_descendants()
print ml.lineages[9]['lineage']
# Out:
# [57, 70, 33, 54, 69, 17, 64, 34, 68, 10]
# {'right': [64, 34, 68, 10], 'left': [57, 70, 33, 54, 69, 17]}
# (((57, (70, 33)), (54, (69, 17))), ((64, 34), (68, 10)))

# %%
ml.draw()
ml.to_newick()
# Out:
# ['(85, (133, (180, (201, 1))));',
#  '(86, (110, 2));',
#  '(3, None);',
#  '(64, (71, (78, 4)));',
#  '(66, (82, (104, (111, (141, 5)))));',
#  '(6, None);',
#  '(7, None);',
# ...
