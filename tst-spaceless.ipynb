# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
SD = pd.read_csv('./spaceless_data/SD.Sat Nov 21 12:51:42 2015stats.csv')
MD = pd.read_csv('./spaceless_data/MD.Sat Nov 21 12:51:56 2015stats.csv')
CSC = pd.read_csv('./spaceless_data/CSC_reg.Sat Nov 21 15:37:41 2015stats.csv')
CSC2 = pd.read_csv('./spaceless_data/CSC_MD.Sat Nov 21 16:05:26 2015stats.csv')


for t in np.unique(SD['t']):
    SDs = SD[SD['t'] == 0.1][['N', 'D']].values
    MDs = MD[MD['t'] == t][['N', 'D']].values
    CSC1s = CSC[CSC['t'] == t][['N', 'D']].values
    CSC2s = CSC2[CSC2['t'] == t][['N', 'D']].values
    plt.figure()
    plt.plot(MDs[:,0], MDs[:,1], 'g', label='MD')
    plt.plot(SDs[:,0], SDs[:,1], 'r', label='SD')
    plt.plot(CSC1s[:,0], CSC1s[:,1], 'b', label='CSC')
    plt.plot(CSC2s[:,0], CSC2s[:,1], 'y', label='MDCSC')
    plt.legend(loc='best')
    plt.title('D statistic for different models (t='+str(t)+' / Includes subsampling)')
    plt.ylabel('D statistic')
    plt.xlabel('Number of Cells, N')

# %%
SD = pd.read_csv('./spaceless_data/SD.Sat Nov 21 15:20:59 2015stats.csv')
MD = pd.read_csv('./spaceless_data/MD.Sat Nov 21 15:21:06 2015stats.csv')
CSC = pd.read_csv('./spaceless_data/CSC_reg.Sat Nov 21 15:31:00 2015stats.csv')
CSC2 = pd.read_csv('./spaceless_data/CSC_MD.Sat Nov 21 16:08:09 2015stats.csv')


for t in np.unique(SD['t']):
    SDs = SD[SD['t'] == 0.1][['N', 'D']].values
    MDs = MD[MD['t'] == t][['N', 'D']].values
    CSC1s = CSC[CSC['t'] == t][['N', 'D']].values
    CSC2s = CSC2[CSC2['t'] == t][['N', 'D']].values
    plt.figure()
    plt.plot(MDs[:,0], MDs[:,1], 'g', label='MD')
    plt.plot(SDs[:,0], SDs[:,1], 'r', label='SD')
    plt.plot(CSC1s[:,0], CSC1s[:,1], 'b', label='CSC')
    plt.plot(CSC2s[:,0], CSC2s[:,1], 'y', label='MDCSC')
    plt.legend(loc='best')
    plt.title('D statistic for different models (t='+str(t)+' / Includes subsampling)')
    plt.ylabel('D statistic')
    plt.xlabel('Number of Cells, N')

# %%
SD = pd.read_csv('./spaceless_data/SD.Sat Nov 21 16:13:49 2015stats.csv')
MD = pd.read_csv('./spaceless_data/MD.Sat Nov 21 16:13:38 2015stats.csv')
CSC = pd.read_csv('./spaceless_data/CSC_reg.Sat Nov 21 16:13:39 2015stats.csv')
CSC2 = pd.read_csv('./spaceless_data/CSC_MD.Sat Nov 21 16:13:55 2015stats.csv')


for t in np.unique(SD['t']):
    SDs = SD[SD['t'] == 0.1][['N', 'D']].values
    MDs = MD[MD['t'] == t][['N', 'D']].values
    CSC1s = CSC[CSC['t'] == t][['N', 'D']].values
    CSC2s = CSC2[CSC2['t'] == t][['N', 'D']].values
    plt.figure()
    plt.plot(MDs[:,0], MDs[:,1], 'g', label='MD')
    plt.plot(SDs[:,0], SDs[:,1], 'r', label='SD')
    plt.plot(CSC1s[:,0], CSC1s[:,1], 'b', label='CSC')
    plt.plot(CSC2s[:,0], CSC2s[:,1], 'y', label='MDCSC')
    plt.legend(loc='best')
    plt.title('D statistic for different models (t='+str(t)+' / Long time)')
    plt.ylabel('D statistic')
    plt.xlabel('Number of Cells, N')
